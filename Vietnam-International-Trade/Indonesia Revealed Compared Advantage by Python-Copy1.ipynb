# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# %matplotlib
# Out:
# Using matplotlib backend: Qt5Agg

# %% [markdown]
# **A value of the RCA above one in goods (or sector) k for country i means that i has a revealed comparative advantage in that sector. a measure of a country’s relative advantage or disadvantage in a specific industry as evidenced by trade flows.**

# %% [markdown]
# ## Load Dataset

# %%
rca = pd.read_csv("core dataset.csv")
rca.head()
# Out:
#    Unnamed: 0  hs07  year    export_val   import_val  export_rca  import_rca  \
# 0           0   1.0  2008  6.343198e+07  358611772.0    2.709450    9.323941
# 1           1   2.0  2008  3.252633e+07  238646027.0    3.339772    3.733699
# 2           2   3.0  2008  2.238172e+09   98839096.0   21.517980    1.280112
# 3           3   4.0  2008  4.052109e+08  859054164.0   88.878893   13.697648
# 4           4   5.0  2008  2.466984e+07   49579023.0   13.126789   16.261980
#
#    export_val_perc  import_val_perc    country
# 0         0.000489         0.003636  indonesia
# 1         0.000251         0.002420  indonesia
# 2         0.017256         0.001002  indonesia
# 3         0.003124         0.008710  indonesia
# 4         0.000190         0.000503  indonesia

# %%
del rca["Unnamed: 0"]
rca.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2880 entries, 0 to 2879
# Data columns (total 9 columns):
# hs07               2880 non-null float64
# year               2880 non-null int64
# export_val         2880 non-null float64
# import_val         2880 non-null float64
# export_rca         2880 non-null float64
# import_rca         2880 non-null float64
# export_val_perc    2880 non-null float64
# import_val_perc    2880 non-null float64
# country            2880 non-null object
# dtypes: float64(7), int64(1), object(1)
# memory usage: 202.6+ KB

# %%
rca["country"].nunique()
# Out:
# 3

# %%
rca.describe()
# Out:
#               hs07        year    export_val    import_val    export_rca  \
# count  2880.000000  2880.00000  2.880000e+03  2.880000e+03   2880.000000
# mean     48.708333  2012.50000  5.623704e+10  5.611821e+10   1617.972744
# std      28.003343     2.87278  2.560536e+11  2.560603e+11   4888.834240
# min       1.000000  2008.00000  5.329027e+04  4.707142e+05      0.002770
# 25%      24.750000  2010.00000  1.219131e+08  2.331184e+08      4.259250
# 50%      48.500000  2012.50000  1.036734e+09  1.160687e+09     16.133000
# 75%      72.250000  2015.00000  2.104188e+10  2.095033e+10   1294.419250
# max      97.000000  2017.00000  3.480827e+12  3.480827e+12  69917.199000
#
#          import_rca  export_val_perc  import_val_perc
# count   2880.000000     2.880000e+03      2880.000000
# mean    1221.682831     1.041667e-02         0.010417
# std     2415.514842     3.026551e-02         0.027087
# min        0.022146     3.351128e-07         0.000003
# 25%        6.347500     5.038395e-04         0.000958
# 50%       21.703000     2.412964e-03         0.003045
# 75%     1510.220000     7.269803e-03         0.008224
# max    17398.917000     4.343699e-01         0.314280

# %% [markdown]
# ## Remove all useless and wrong features

# %%
rca.columns
# Out:
# Index(['hs07', 'year', 'export_val', 'import_val', 'export_rca', 'import_rca',
#        'export_val_perc', 'import_val_perc', 'country'],
#       dtype='object')

# %%
del rca["export_rca"], rca["import_rca"]
rca.head()
# Out:
#    hs07  year    export_val   import_val  export_val_perc  import_val_perc  \
# 0   1.0  2008  6.343198e+07  358611772.0         0.000489         0.003636
# 1   2.0  2008  3.252633e+07  238646027.0         0.000251         0.002420
# 2   3.0  2008  2.238172e+09   98839096.0         0.017256         0.001002
# 3   4.0  2008  4.052109e+08  859054164.0         0.003124         0.008710
# 4   5.0  2008  2.466984e+07   49579023.0         0.000190         0.000503
#
#      country
# 0  indonesia
# 1  indonesia
# 2  indonesia
# 3  indonesia
# 4  indonesia

# %%
indonesia = rca.loc[rca["country"]=="indonesia"]
indonesia = indonesia.reset_index()
indonesia.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 960 entries, 0 to 959
# Data columns (total 8 columns):
# index              960 non-null int64
# hs07               960 non-null float64
# year               960 non-null int64
# export_val         960 non-null float64
# import_val         960 non-null float64
# export_val_perc    960 non-null float64
# import_val_perc    960 non-null float64
# country            960 non-null object
# dtypes: float64(5), int64(2), object(1)
# memory usage: 60.1+ KB

# %%
indonesia.tail()
# Out:
#      index  hs07  year    export_val    import_val  export_val_perc  \
# 955    955  93.0  2017  8.734688e+05  3.808504e+08         0.000005
# 956    956  94.0  2017  2.050951e+09  8.455012e+08         0.010990
# 957    957  95.0  2017  7.321279e+08  3.205711e+08         0.003923
# 958    958  96.0  2017  3.029797e+08  4.565936e+08         0.001624
# 959    959  97.0  2017  2.167994e+08  3.099755e+06         0.001162
#
#      import_val_perc    country
# 955         0.002477  indonesia
# 956         0.005500  indonesia
# 957         0.002085  indonesia
# 958         0.002970  indonesia
# 959         0.000020  indonesia

# %%
dunia = rca.loc[rca["country"]=="ALL"]
dunia.rename(columns={"year":"year1","hs07": "hs07_du", "export_val_perc":"export_val_perc_du", "import_val_perc":"import_val_perc_du"}, inplace=True)
dunia = dunia.reset_index()
dunia.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 960 entries, 0 to 959
# Data columns (total 8 columns):
# index                 960 non-null int64
# hs07_du               960 non-null float64
# year1                 960 non-null int64
# export_val            960 non-null float64
# import_val            960 non-null float64
# export_val_perc_du    960 non-null float64
# import_val_perc_du    960 non-null float64
# country               960 non-null object
# dtypes: float64(5), int64(2), object(1)
# memory usage: 60.1+ KB
# C:\Users\LENOVO\Anaconda3\lib\site-packages\pandas\core\frame.py:3778: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)

# %%
dunia.tail()
# Out:
#      index  hs07_du  year1    export_val    import_val  export_val_perc_du  \
# 955   2875     93.0   2017  9.222621e+09  9.222621e+09            0.000577
# 956   2876     94.0   2017  2.312774e+11  2.312774e+11            0.014466
# 957   2877     95.0   2017  1.161837e+11  1.161837e+11            0.007267
# 958   2878     96.0   2017  3.202722e+10  3.202722e+10            0.002003
# 959   2879     97.0   2017  1.908515e+10  1.908515e+10            0.001194
#
#      import_val_perc_du country
# 955            0.000577     ALL
# 956            0.014466     ALL
# 957            0.007267     ALL
# 958            0.002003     ALL
# 959            0.001194     ALL

# %%
oi = pd.concat([indonesia, dunia], axis=1)
oi.head()
# Out:
#    index  hs07  year    export_val   import_val  export_val_perc  \
# 0      0   1.0  2008  6.343198e+07  358611772.0         0.000489
# 1      1   2.0  2008  3.252633e+07  238646027.0         0.000251
# 2      2   3.0  2008  2.238172e+09   98839096.0         0.017256
# 3      3   4.0  2008  4.052109e+08  859054164.0         0.003124
# 4      4   5.0  2008  2.466984e+07   49579023.0         0.000190
#
#    import_val_perc    country  index  hs07_du  year1    export_val  \
# 0         0.003636  indonesia   1920      1.0   2008  1.706110e+10
# 1         0.002420  indonesia   1921      2.0   2008  9.630627e+10
# 2         0.001002  indonesia   1922      3.0   2008  7.751119e+10
# 3         0.008710  indonesia   1923      4.0   2008  7.160095e+10
# 4         0.000503  indonesia   1924      5.0   2008  7.225888e+09
#
#      import_val  export_val_perc_du  import_val_perc_du country
# 0  1.706110e+10            0.001111            0.001111     ALL
# 1  9.630627e+10            0.006270            0.006270     ALL
# 2  7.751119e+10            0.005046            0.005046     ALL
# 3  7.160095e+10            0.004661            0.004661     ALL
# 4  7.225888e+09            0.000470            0.000470     ALL

# %%
oi.tail()
# Out:
#      index  hs07  year    export_val    import_val  export_val_perc  \
# 955    955  93.0  2017  8.734688e+05  3.808504e+08         0.000005
# 956    956  94.0  2017  2.050951e+09  8.455012e+08         0.010990
# 957    957  95.0  2017  7.321279e+08  3.205711e+08         0.003923
# 958    958  96.0  2017  3.029797e+08  4.565936e+08         0.001624
# 959    959  97.0  2017  2.167994e+08  3.099755e+06         0.001162
#
#      import_val_perc    country  index  hs07_du  year1    export_val  \
# 955         0.002477  indonesia   2875     93.0   2017  9.222621e+09
# 956         0.005500  indonesia   2876     94.0   2017  2.312774e+11
# 957         0.002085  indonesia   2877     95.0   2017  1.161837e+11
# 958         0.002970  indonesia   2878     96.0   2017  3.202722e+10
# 959         0.000020  indonesia   2879     97.0   2017  1.908515e+10
#
#        import_val  export_val_perc_du  import_val_perc_du country
# 955  9.222621e+09            0.000577            0.000577     ALL
# 956  2.312774e+11            0.014466            0.014466     ALL
# 957  1.161837e+11            0.007267            0.007267     ALL
# 958  3.202722e+10            0.002003            0.002003     ALL
# 959  1.908515e+10            0.001194            0.001194     ALL

# %% [markdown]
# ### Calculating RCA within HS07 Code

# %%
def coba(frame1):
    for z in frame1:
        frame1["rca_x"] = frame1["export_val_perc"] / frame1["export_val_perc_du"]
        frame1["rca_i"] = frame1["import_val_perc"] / frame1["import_val_perc_du"]
    return frame1

# %%
gehu = coba(oi)
gehu.tail()
# Out:
#      index  hs07  year    export_val    import_val  export_val_perc  \
# 955    955  93.0  2017  8.734688e+05  3.808504e+08         0.000005
# 956    956  94.0  2017  2.050951e+09  8.455012e+08         0.010990
# 957    957  95.0  2017  7.321279e+08  3.205711e+08         0.003923
# 958    958  96.0  2017  3.029797e+08  4.565936e+08         0.001624
# 959    959  97.0  2017  2.167994e+08  3.099755e+06         0.001162
#
#      import_val_perc    country  index  hs07_du  year1    export_val  \
# 955         0.002477  indonesia   2875     93.0   2017  9.222621e+09
# 956         0.005500  indonesia   2876     94.0   2017  2.312774e+11
# 957         0.002085  indonesia   2877     95.0   2017  1.161837e+11
# 958         0.002970  indonesia   2878     96.0   2017  3.202722e+10
# 959         0.000020  indonesia   2879     97.0   2017  1.908515e+10
#
#        import_val  export_val_perc_du  import_val_perc_du country     rca_x  \
# 955  9.222621e+09            0.000577            0.000577     ALL  0.008114
# 956  2.312774e+11            0.014466            0.014466     ALL  0.759744
# 957  1.161837e+11            0.007267            0.007267     ALL  0.539867
# 958  3.202722e+10            0.002003            0.002003     ALL  0.810474
# 959  1.908515e+10            0.001194            0.001194     ALL  0.973212
#
#         rca_i
# 955  4.294625
# 956  0.380195
# 957  0.286949
# 958  1.482640
# 959  0.016891

# %%
clean_rca = gehu[['year','hs07', "rca_x", "rca_i"]].copy()
clean_rca.head()
# Out:
#    year  hs07     rca_x     rca_i
# 0  2008   1.0  0.440305  3.273499
# 1  2008   2.0  0.039998  0.385918
# 2  2008   3.0  3.419652  0.198591
# 3  2008   4.0  0.670217  1.868515
# 4  2008   5.0  0.404323  1.068567

# %% [markdown]
# ## the RCA Graph by HS07 Code Over Year

# %%
clean_rca.to_csv("indonesia_clean_rca.csv")

# %%
plt.figure(figsize=(13,8))
sns.pointplot(x="year", y="rca_x", hue="hs07", data=clean_rca, width=.1)
plt.legend(loc=9, bbox_to_anchor=(0.5, -0.1), ncol=11)
plt.grid(True)
plt.title("Indonesia RCA Map by Product", size=20)
plt.show()

# %% [markdown]
# ### Most Consistent to Be Highest and Lowest RCA Over Years

# %%
#search highest within a year
def  ayo(data, tahun):
    hijau = data.loc[data["year"]== tahun]
    hijau = hijau.set_index("hs07")
    hijau = hijau["rca_x"].nlargest(3)
    hijau = hijau.to_frame()
    hijau["year"] = tahun
    hijau = hijau.reset_index()
    return (hijau)

def  ayu(data, tahun):
    hijau = data.loc[data["year"]== tahun]
    hijau = hijau.set_index("hs07")
    hijau = hijau["rca_x"].nsmallest(1)
    hijau = hijau.to_frame()
    hijau["year"] = tahun
    hijau = hijau.reset_index()
    return (hijau)

# %%
w08 = ayo(clean_rca, 2008)
w09 = ayo(clean_rca, 2009)
w10 = ayo(clean_rca, 2010)
w11 = ayo(clean_rca, 2011)
w12 = ayo(clean_rca, 2012)
w13 = ayo(clean_rca, 2013)
w14 = ayo(clean_rca, 2014)
w15 = ayo(clean_rca, 2015)
w16 = ayo(clean_rca, 2016)
w17 = ayo(clean_rca, 2017)
u08 = ayu(clean_rca, 2008)
u09 = ayu(clean_rca, 2009)
u10 = ayu(clean_rca, 2010)
u11 = ayu(clean_rca, 2011)
u12 = ayu(clean_rca, 2012)
u13 = ayu(clean_rca, 2013)
u14 = ayu(clean_rca, 2014)
u15 = ayu(clean_rca, 2015)
u16 = ayu(clean_rca, 2016)
u17 = ayu(clean_rca, 2017)

# %%
iit = pd.concat([u08, u09, u10, u11, u12, u13, u14, u15, u16, u17, w08, w09, w10, w11, w12, w13, w14, w15, w16, w17], ignore_index=True)
iit.head()
# Out:
#    hs07     rca_x  year
# 0  43.0  0.003514  2008
# 1  43.0  0.005286  2009
# 2  37.0  0.014356  2010
# 3  10.0  0.007019  2011
# 4  37.0  0.008875  2012

# %%
print (iit["hs07"].unique())
# Out:
# [43. 37. 10. 45. 93. 80. 15. 92.]

# %%
ehu = clean_rca.set_index("hs07")
mostrca = ehu.loc[iit["hs07"].unique()]
mostrca = mostrca.reset_index()
mostrca.head()
# Out:
#    hs07  year     rca_x     rca_i
# 0  43.0  2008  0.003514  0.087828
# 1  43.0  2009  0.005286  0.051508
# 2  43.0  2010  0.023910  0.058870
# 3  43.0  2011  0.017350  0.062025
# 4  43.0  2012  0.029531  0.045927

# %%
labe = mostrca["hs07"].unique()
mark = [",", ".", "o", "v", ">", "<", "1", "2", "3", "4"]
plt.figure(figsize=(9,5.6))
sns.pointplot(x="year", y="rca_x", hue="hs07", data=mostrca, markers= mark, dashes=False, legend=False)
plt.legend(loc=1, ncol=2)
plt.title("Most and Worst Competitive Product in Indonesia", size=20)
plt.grid(True)
plt.savefig("RCA Indo.png")
plt.show()

# %%
mark = [",", ".", "o", "v", "^", "<", "1", "2", "3", "4"]
plt.figure(figsize=(9,5.6))
sns.pointplot(x="year", y="rca_x", hue="hs07", data=iit, markers= mark, width=.1)
plt.legend(loc=1, ncol=2)
plt.grid(True)
plt.title("Most and Worst Competitive Product", size=20)
plt.show()
